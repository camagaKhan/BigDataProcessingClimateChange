# %%
import pandas as pd

# %%
data = pd.read_csv('../Data/DP_LIVE_07052023161846329.csv')
data
# Out:
#       LOCATION    INDICATOR SUBJECT    MEASURE FREQUENCY  TIME       Value  \
# 0          AUS  AIREMISSION     CO2  MLN_TONNE         A  1960   88.452975
# 1          AUS  AIREMISSION     CO2  MLN_TONNE         A  1961   91.890271
# 2          AUS  AIREMISSION     CO2  MLN_TONNE         A  1962   95.013703
# 3          AUS  AIREMISSION     CO2  MLN_TONNE         A  1963  100.648641
# 4          AUS  AIREMISSION     CO2  MLN_TONNE         A  1964  105.988250
# ...        ...          ...     ...        ...       ...   ...         ...
# 35504     OECD  AIREMISSION     CO2  KG_CO2USD         A  2017    4.820000
# 35505     OECD  AIREMISSION     CO2  KG_CO2USD         A  2018    4.930000
# 35506     OECD  AIREMISSION     CO2  KG_CO2USD         A  2019    5.180000
# 35507     OECD  AIREMISSION     CO2  KG_CO2USD         A  2020    5.450000
# 35508     OECD  AIREMISSION     CO2  KG_CO2USD         A  2021    5.460000
#
#       Flag Codes
# 0            NaN
# 1            NaN
# ...

# %%
data = pd.read_csv('../Data/GHG_data.csv')
data
# Out:
#       PREFIX    Country  POL         Pollutant           VAR  \
# 0        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 1        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 2        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 3        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 4        AUS  Australia  GHG  Greenhouse gases         TOTAL
# ...      ...        ...  ...               ...           ...
# 75701    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75702    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75703    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75704    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75705    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
#
#                                      Variable   YEA  Year    UnitCode  \
# 0           Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 1           Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# ...

# %%
data.columns
# Out:
# Index(['PREFIX', 'Country', 'POL', 'Pollutant', 'VAR', 'Variable', 'YEA',
#        'Year', 'UnitCode', 'Unit', 'PowerCodeCode', 'PowerCode',
#        'ReferencePeriodCode', 'ReferencePeriod', 'Value', 'FlagCodes',
#        'Flags'],
#       dtype='object')

# %% [markdown]
# https://data.oecd.org/air/air-pollution-effects.htm#indicator-chart

# %%
data.dtypes
# Out:
# PREFIX                  object
# Country                 object
# POL                     object
# Pollutant               object
# VAR                     object
# Variable                object
# YEA                      int64
# Year                     int64
# UnitCode                object
# Unit                    object
# PowerCodeCode            int64
# PowerCode               object
# ReferencePeriodCode    float64
# ReferencePeriod        float64
# Value                  float64
# FlagCodes               object
# Flags                   object
# dtype: object

# %%
data['PREFIX'].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'CHL', 'EST', 'ISR', 'RUS', 'SVN', 'LVA',
#        'LTU', 'OECD', 'OECDE', 'BRA', 'CHN', 'COL', 'CRI', 'IND', 'IDN',
#        'ZAF', 'ARG', 'OECDAO', 'OECDAM', 'LIE', 'BGR', 'UKR', 'ROU',
#        'SAU', 'MLT', 'CYP', 'KAZ', 'PER', 'MCO', 'BLR', 'HRV', 'IRN',
#        'EU27_2020'], dtype=object)

# %%
data[pd.notna(data['Flags'])]
# Out:
#       PREFIX Country  POL         Pollutant           VAR  \
# 23146    MEX  Mexico  GHG  Greenhouse gases        LULUCF
# 29069    MEX  Mexico  GHG  Greenhouse gases    TOTAL_LULU
# 64404    MEX  Mexico  GHG  Greenhouse gases  GHG_GDP_LULU
# 66158    MEX  Mexico  GHG  Greenhouse gases  GHG_CAP_LULU
#
#                                               Variable   YEA  Year  \
# 23146  Land use, land-use change and forestry (LULUCF)  2000  2000
# 29069                Total  emissions including LULUCF  2000  2000
# 64404           Total GHG incl. LULUCF per unit of GDP  2000  2000
# 66158                Total GHG incl. LULUCF per capita  2000  2000
#
#          UnitCode                      Unit  PowerCodeCode  PowerCode  \
# 23146  T_CO2_EQVT  Tonnes of CO2 equivalent              3  Thousands
# 29069  T_CO2_EQVT  Tonnes of CO2 equivalent              3  Thousands
# 64404         NaN                       NaN              0      Units
# ...

# %%
arr = ['LTU', 'TUR', 'SVN', 'ITA', 'HUN', 'LVA', 'ISL', 'SWE', 'CHL',
       'OECD', 'LIE', 'CZE', 'MLT', 'ZAF', 'DNK', 'AUT', 'ROU', 'KAZ',
       'OECDE', 'ESP', 'IDN', 'CYP', 'CAN', 'IRL', 'SVK', 'NZL', 'JPN',
       'IRN', 'CHN', 'CHE', 'FIN', 'BGR', 'ISR', 'USA', 'UKR', 'CRI',
       'HRV', 'EST', 'COL', 'AUS', 'LUX', 'BRA', 'PRT', 'RUS', 'BEL',
       'KOR', 'MEX', 'PER', 'GBR', 'ARG', 'GRC', 'BLR', 'DEU', 'MCO',
       'NOR', 'POL', 'SAU', 'NLD', 'IND']

data3 = data[data['PREFIX'].apply(lambda x: x in arr)]

data3
# Out:
#       PREFIX    Country  POL         Pollutant           VAR  \
# 0        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 1        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 2        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 3        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 4        AUS  Australia  GHG  Greenhouse gases         TOTAL
# ...      ...        ...  ...               ...           ...
# 75701    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75702    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75703    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75704    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75705    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
#
#                                      Variable   YEA  Year    UnitCode  \
# 0           Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 1           Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# ...

# %%
#Potential topics for kafka
data3['POL'].unique()
# Out:
# array(['GHG', 'CO2', 'CH4', 'N2O', 'HFC', 'PFC', 'SF6', 'NF3', 'HFC_PFC'],
#       dtype=object)

# %%
data3 = data3[data3['POL'] == 'GHG']

# %%
data3
# Out:
#       PREFIX    Country  POL         Pollutant           VAR  \
# 0        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 1        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 2        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 3        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 4        AUS  Australia  GHG  Greenhouse gases         TOTAL
# ...      ...        ...  ...               ...           ...
# 75701    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75702    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75703    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75704    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75705    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
#
#                                      Variable   YEA  Year    UnitCode  \
# 0           Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 1           Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# ...

# %%
data3.to_csv('../Data/ghg.csv', index=False)
