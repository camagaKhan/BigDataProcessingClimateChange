# %%
import pandas as pd

ghg, temperature = pd.read_csv('../Data/GHG_data.csv'), pd.read_csv('../Data/temperature.csv')

# %%
ghg
# Out:
#       PREFIX    Country  POL         Pollutant           VAR  \
# 0        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 1        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 2        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 3        AUS  Australia  GHG  Greenhouse gases         TOTAL
# 4        AUS  Australia  GHG  Greenhouse gases         TOTAL
# ...      ...        ...  ...               ...           ...
# 75701    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75702    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75703    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75704    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75705    PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
#
#                                      Variable   YEA  Year    UnitCode  \
# 0           Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 1           Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# 2           Total  emissions excluding LULUCF  1992  1992  T_CO2_EQVT
# 3           Total  emissions excluding LULUCF  1993  1993  T_CO2_EQVT
# 4           Total  emissions excluding LULUCF  1994  1994  T_CO2_EQVT
# ...                                       ...   ...   ...         ...
# 75701  Total GHG incl. LULUCF per unit of GDP  2005  2005         NaN
# 75702  Total GHG incl. LULUCF per unit of GDP  2010  2010         NaN
# 75703  Total GHG incl. LULUCF per unit of GDP  2012  2012         NaN
# 75704  Total GHG incl. LULUCF per unit of GDP  2014  2014         NaN
# 75705  Total GHG incl. LULUCF per unit of GDP  2016  2016         NaN
#
#                            Unit  PowerCodeCode  PowerCode  \
# 0      Tonnes of CO2 equivalent              3  Thousands
# 1      Tonnes of CO2 equivalent              3  Thousands
# 2      Tonnes of CO2 equivalent              3  Thousands
# 3      Tonnes of CO2 equivalent              3  Thousands
# 4      Tonnes of CO2 equivalent              3  Thousands
# ...                         ...            ...        ...
# 75701                       NaN              0      Units
# 75702                       NaN              0      Units
# 75703                       NaN              0      Units
# 75704                       NaN              0      Units
# 75705                       NaN              0      Units
#
#        ReferencePeriodCode  ReferencePeriod       Value FlagCodes Flags
# 0                      NaN              NaN  425624.307       NaN   NaN
# 1                      NaN              NaN  425686.445       NaN   NaN
# 2                      NaN              NaN  429473.085       NaN   NaN
# 3                      NaN              NaN  430381.731       NaN   NaN
# 4                      NaN              NaN  430848.498       NaN   NaN
# ...                    ...              ...         ...       ...   ...
# 75701                  NaN              NaN       0.773       NaN   NaN
# 75702                  NaN              NaN       0.612       NaN   NaN
# 75703                  NaN              NaN       0.565       NaN   NaN
# 75704                  NaN              NaN       0.579       NaN   NaN
# 75705                  NaN              NaN       0.560       NaN   NaN
#
# [75706 rows x 17 columns]

# %%
temperature
# Out:
#                        REF_AREA                            Measure  \
# 0                         Yemen  TEMP_C: Annual temperature change
# 1                         Yemen  TEMP_C: Annual temperature change
# 2                         Yemen  TEMP_C: Annual temperature change
# 3                         Yemen  TEMP_C: Annual temperature change
# 4                         Yemen  TEMP_C: Annual temperature change
# ...                         ...                                ...
# 30009  Yorkshire and The Humber  TEMP_C: Annual temperature change
# 30010  Yorkshire and The Humber  TEMP_C: Annual temperature change
# 30011  Yorkshire and The Humber  TEMP_C: Annual temperature change
# 30012  Yorkshire and The Humber  TEMP_C: Annual temperature change
# 30013  Yorkshire and The Humber  TEMP_C: Annual temperature change
#
#              UNIT_MEASURE  TIME_PERIOD  OBS_VALUE REF_CODE
# 0      C: Degrees celsius         1979      -0.55      YEM
# 1      C: Degrees celsius         1980      -0.17      YEM
# 2      C: Degrees celsius         1981      -0.48      YEM
# 3      C: Degrees celsius         1982      -0.53      YEM
# 4      C: Degrees celsius         1983      -0.89      YEM
# ...                   ...          ...        ...      ...
# 30009  C: Degrees celsius         2017       0.73      UKE
# 30010  C: Degrees celsius         2018       0.62      UKE
# 30011  C: Degrees celsius         2019       0.53      UKE
# 30012  C: Degrees celsius         2020       0.75      UKE
# 30013  C: Degrees celsius         2021       0.48      UKE
#
# [30014 rows x 6 columns]

# %%
ghg_df = ghg[ghg['PREFIX'] == 'MLT']

# %%
temp_df = temperature[temperature['REF_CODE'] == 'MLT']

# %%
ghg_df['Variable'].unique()
# Out:
# array(['1 - Energy', 'Total GHG excl. LULUCF, Index 1990=100',
#        'Land use, land-use change and forestry (LULUCF)',
#        'Total  emissions excluding LULUCF',
#        '1A4 - Residential and other sectors', '1A1 - Energy Industries',
#        'Total GHG excl. LULUCF, Index 2000=100', '1A3 - Transport',
#        '3 - Agriculture',
#        '1A2 - Manufacturing industries and construction',
#        '1A5 - Energy - Other', '2- Industrial processes and product use',
#        '5 - Waste', '1A4 - Residential and other sectors\t',
#        'Total  emissions including LULUCF'], dtype=object)

# %%
ghg_df[ghg_df['Variable']=='Total  emissions excluding LULUCF']
# Out:
#       PREFIX Country  POL         Pollutant    VAR  \
# 58475    MLT   Malta  CH4           Methane  TOTAL
# 58476    MLT   Malta  CH4           Methane  TOTAL
# 58477    MLT   Malta  CH4           Methane  TOTAL
# 58478    MLT   Malta  CH4           Methane  TOTAL
# 58479    MLT   Malta  CH4           Methane  TOTAL
# ...      ...     ...  ...               ...    ...
# 71741    MLT   Malta  GHG  Greenhouse gases  TOTAL
# 71742    MLT   Malta  GHG  Greenhouse gases  TOTAL
# 71743    MLT   Malta  GHG  Greenhouse gases  TOTAL
# 71744    MLT   Malta  GHG  Greenhouse gases  TOTAL
# 71745    MLT   Malta  GHG  Greenhouse gases  TOTAL
#
#                                 Variable   YEA  Year    UnitCode  \
# 58475  Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 58476  Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# 58477  Total  emissions excluding LULUCF  1992  1992  T_CO2_EQVT
# 58478  Total  emissions excluding LULUCF  1993  1993  T_CO2_EQVT
# 58479  Total  emissions excluding LULUCF  1994  1994  T_CO2_EQVT
# ...                                  ...   ...   ...         ...
# 71741  Total  emissions excluding LULUCF  2016  2016  T_CO2_EQVT
# 71742  Total  emissions excluding LULUCF  2017  2017  T_CO2_EQVT
# 71743  Total  emissions excluding LULUCF  2018  2018  T_CO2_EQVT
# 71744  Total  emissions excluding LULUCF  2019  2019  T_CO2_EQVT
# 71745  Total  emissions excluding LULUCF  2020  2020  T_CO2_EQVT
#
#                            Unit  PowerCodeCode  PowerCode  \
# 58475  Tonnes of CO2 equivalent              3  Thousands
# 58476  Tonnes of CO2 equivalent              3  Thousands
# 58477  Tonnes of CO2 equivalent              3  Thousands
# 58478  Tonnes of CO2 equivalent              3  Thousands
# 58479  Tonnes of CO2 equivalent              3  Thousands
# ...                         ...            ...        ...
# 71741  Tonnes of CO2 equivalent              3  Thousands
# 71742  Tonnes of CO2 equivalent              3  Thousands
# 71743  Tonnes of CO2 equivalent              3  Thousands
# 71744  Tonnes of CO2 equivalent              3  Thousands
# 71745  Tonnes of CO2 equivalent              3  Thousands
#
#        ReferencePeriodCode  ReferencePeriod     Value FlagCodes Flags
# 58475                  NaN              NaN   125.190       NaN   NaN
# 58476                  NaN              NaN   133.206       NaN   NaN
# 58477                  NaN              NaN   140.870       NaN   NaN
# 58478                  NaN              NaN   147.923       NaN   NaN
# 58479                  NaN              NaN   153.232       NaN   NaN
# ...                    ...              ...       ...       ...   ...
# 71741                  NaN              NaN  1835.781       NaN   NaN
# 71742                  NaN              NaN  2018.050       NaN   NaN
# 71743                  NaN              NaN  2030.014       NaN   NaN
# 71744                  NaN              NaN  2131.763       NaN   NaN
# 71745                  NaN              NaN  2121.590       NaN   NaN
#
# [196 rows x 17 columns]

# %%
temp_df = temp_df.rename(columns={'TIME_PERIOD': 'Year'})
temp_df
# Out:
#      REF_AREA                            Measure        UNIT_MEASURE  Year  \
# 7482    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1979
# 7483    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1980
# 7484    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1981
# 7485    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1982
# 7486    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1983
# 7487    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1984
# 7488    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1985
# 7489    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1986
# 7490    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1987
# 7491    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1988
# 7492    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1989
# 7493    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1990
# 7494    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1991
# 7495    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1992
# 7496    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1993
# 7497    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1994
# 7498    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1995
# 7499    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1996
# 7500    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1997
# 7501    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1998
# 7502    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  1999
# 7503    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2000
# 7504    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2001
# 7505    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2002
# 7506    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2003
# 7507    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2004
# 7508    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2005
# 7509    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2006
# 7510    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2007
# 7511    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2008
# 7512    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2009
# 7513    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2010
# 7514    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2011
# 7515    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2012
# 7516    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2013
# 7517    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2014
# 7518    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2015
# 7519    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2016
# 7520    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2017
# 7521    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2018
# 7522    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2019
# 7523    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2020
# 7524    Malta  TEMP_C: Annual temperature change  C: Degrees celsius  2021
#
#       OBS_VALUE REF_CODE
# 7482      -0.31      MLT
# 7483      -0.95      MLT
# 7484      -0.69      MLT
# 7485       0.03      MLT
# 7486      -0.43      MLT
# 7487      -0.75      MLT
# 7488      -0.15      MLT
# 7489      -0.29      MLT
# 7490      -0.15      MLT
# 7491       0.09      MLT
# 7492      -0.16      MLT
# 7493       0.44      MLT
# 7494      -0.44      MLT
# 7495      -0.16      MLT
# 7496      -0.06      MLT
# 7497       0.47      MLT
# 7498      -0.17      MLT
# 7499      -0.33      MLT
# 7500       0.09      MLT
# 7501      -0.17      MLT
# 7502       0.19      MLT
# 7503       0.12      MLT
# 7504       0.28      MLT
# 7505       0.20      MLT
# 7506       0.67      MLT
# 7507       0.06      MLT
# 7508      -0.31      MLT
# 7509       0.22      MLT
# 7510       0.49      MLT
# 7511       0.44      MLT
# 7512       0.21      MLT
# 7513       0.24      MLT
# 7514       0.10      MLT
# 7515       0.60      MLT
# 7516       0.33      MLT
# 7517       0.52      MLT
# 7518       0.48      MLT
# 7519       0.59      MLT
# 7520       0.39      MLT
# 7521       0.67      MLT
# 7522       0.43      MLT
# 7523       0.72      MLT
# 7524       0.94      MLT

# %%
import matplotlib.pyplot as plt

# Merge the temperature and GHG datasets based on the 'Year' column
merged_data = pd.merge(temp_df, ghg_df, on='Year', how='inner')

# Plotting temperature and GHG together
plt.scatter(merged_data['OBS_VALUE'], merged_data['Value'])

# Set labels and title
plt.xlabel('Temperature')
plt.ylabel('Emissions')
plt.title('Temperature and GHG')
plt.grid()

# Show the plot
plt.show()

# %%
merged_data[['OBS_VALUE', 'Value']].corr()
# Out:
#            OBS_VALUE     Value
# OBS_VALUE   1.000000 -0.019782
# Value      -0.019782  1.000000

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

# %%
X_train, X_test = train_test_split(merged_data, random_state=1, test_size=.3)

# %%
len(X_train), len(X_test)
# Out:
# (807, 346)

# %%
X, y_train = X_train[['Year','Value']], X_train['OBS_VALUE']
x_test, y_test = X_test[['Year', 'Value']], X_test['OBS_VALUE']
model = LinearRegression()
#model.fit(X, y_train)

scaler = StandardScaler()
scaler.fit(X, y_train)
X = scaler.transform(X)
x_test = scaler.transform(x_test)

pca = PCA(n_components=1, random_state=1)
pca.fit(X)
X = pca.transform(X)
x_test = pca.transform(x_test)

model.fit(X, y_train)

model.score(X, y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the regression evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Mean Absolute Error (MAE):', mae)
print('Coefficient of Determination (R-squared):', r2)
# Out:
# Mean Squared Error (MSE): 0.07559976113397225
# Mean Absolute Error (MAE): 0.22137323016483068
# Coefficient of Determination (R-squared): 0.2485982251781108

# %%
y_test, y_pred
# Out:
# (998    0.59
#  439    0.20
#  561   -0.31
#  201   -0.17
#  548   -0.31
#         ...
#  817    0.60
#  437    0.20
#  464    0.20
#  151    0.47
#  783    0.10
#  Name: OBS_VALUE, Length: 346, dtype: float64,
#  array([ 0.38857149,  0.22577061,  0.2624162 ,  0.15525822,  0.26317492,
#          0.31120084,  0.20067464,  0.30020619,  0.129809  ,  0.34504927,
#          0.24496621,  0.1186557 ,  0.15170715,  0.25569139,  0.27505159,
#          0.31825401,  0.24461481,  0.24056285,  0.43063813,  0.05880931,
#          0.34472588,  0.34015549,  0.15344661,  0.39761989,  0.37245751,
#          0.33073215,  0.42158073,  0.21088714,  0.31060145,  0.22234469,
#          0.10917898,  0.2440082 ,  0.15176611,  0.11757932,  0.33671588,
#          0.21674759,  0.31927874,  0.29599338,  0.28766605,  0.31773546,
#          0.06152097,  0.12780618,  0.35501984,  0.37798236,  0.17730397,
#          0.22366581,  0.26670281,  0.40006851,  0.31902289,  0.01376956,
#          0.17796678,  0.16349205,  0.13029213,  0.25326935,  0.29670502,
#          0.10900726,  0.32225719,  0.38701608,  0.16423923,  0.06792078,
#          0.23991272,  0.18907759,  0.26782366,  0.24451906,  0.35788956,
#          0.00736035,  0.33340295,  0.30015972,  0.31991274,  0.11110249,
#          0.37930077,  0.22919541,  0.13089529,  0.38625076,  0.30005821,
#          0.10713408,  0.24012275,  0.30805982,  0.25321044,  0.3183455 ,
#          0.11866682,  0.3641816 ,  0.14152432,  0.21834027,  0.40831385,
#          0.32243104,  0.17319051,  0.21642858,  0.09988195,  0.19978309,
#          0.36867448,  0.13099475,  0.38336969,  0.2196775 ,  0.2333332 ,
#          0.34322903,  0.15248754,  0.14457627,  0.30715429,  0.25549297,
#          0.16305206,  0.37482775,  0.02518021,  0.11129318,  0.20013775,
#          0.144811  ,  0.39905788,  0.38895048,  0.2491747 ,  0.10010397,
#          0.38539769,  0.29674399,  0.14406132,  0.39992873,  0.36300306,
#          0.31369403,  0.2668667 ,  0.32199975,  0.17407063, -0.30547923,
#          0.17781108,  0.1889154 ,  0.14637712,  0.13340873,  0.18359606,
#          0.02452647,  0.27797897,  0.35566141,  0.13351811,  0.16684454,
#          0.18522956,  0.23906189,  0.15559411,  0.02218126,  0.34452194,
#          0.24112743,  0.40551992,  0.3636198 ,  0.18874479,  0.25120706,
#          0.27502185,  0.43249833,  0.09961861,  0.28611547,  0.12180058,
#          0.15574455, -0.32684996,  0.27373076,  0.10784702,  0.17796709,
#          0.43340923,  0.28199687,  0.32939865,  0.26387107,  0.39466752,
#          0.36445167,  0.30872391,  0.29564143,  0.11120863,  0.38925331,
#         -0.31913396,  0.42230051, -0.3963505 ,  0.35558141,  0.23824714,
#          0.27458627,  0.15175856,  0.2000184 ,  0.3279016 ,  0.28468737,
#          0.09631995,  0.120041  ,  0.14463166,  0.06284198,  0.10775652,
#          0.15557321,  0.37166458,  0.16701666,  0.2545054 ,  0.39008225,
#          0.22489432,  0.26994085,  0.29877847,  0.16095034,  0.41118121,
#          0.41132343,  0.15198661,  0.25153433,  0.23264443,  0.3446216 ,
#          0.14269734,  0.09970929,  0.17786172,  0.22980666,  0.19634199,
#          0.42215501,  0.35537968,  0.22251464,  0.25577054,  0.32903681,
#          0.24081959,  0.3224278 ,  0.31128984,  0.34708513,  0.29598524,
#          0.24904403, -0.38523807,  0.23922397,  0.36466778,  0.23091391,
#          0.35565295,  0.09558336, -0.65050785,  0.35160797,  0.21125003,
#          0.41630642,  0.24445235,  0.09199371,  0.3854346 ,  0.18155487,
#          0.35564001,  0.37799318,  0.11806098,  0.11870954,  0.19773525,
#          0.38211452,  0.35160933,  0.39884243,  0.2404389 ,  0.33353926,
#          0.17054788,  0.18907967,  0.31844235,  0.16309711,  0.31942768,
#          0.10355277,  0.3444029 ,  0.03351083,  0.30791815,  0.12888897,
#          0.21814765,  0.3199808 ,  0.28886065,  0.18514864,  0.14086305,
#          0.19445931,  0.31835358,  0.16269408,  0.31698227,  0.3778425 ,
#          0.14967171,  0.15255571,  0.18841744,  0.27445182, -0.30191383,
#          0.24368934,  0.21431245,  0.410053  ,  0.37798607,  0.34398767,
#          0.38787423,  0.16362955,  0.10013776,  0.22939097,  0.43353979,
#          0.28658488,  0.43045616,  0.05229385,  0.20825004,  0.40562398,
#          0.38701983,  0.27657497,  0.33015822,  0.2445644 ,  0.14076498,
#          0.35360758,  0.24401523,  0.37966968,  0.1492119 ,  0.37644136,
#          0.18902533,  0.19550791,  0.08176314,  0.20543103,  0.19668236,
#          0.43251652,  0.09822426,  0.09764337,  0.34184713,  0.18890748,
#          0.3665597 ,  0.23346943,  0.26334947,  0.28449246,  0.12228205,
#          0.27785653,  0.27555245,  0.09534697,  0.4224958 ,  0.22939723,
#          0.34558353,  0.12117755,  0.28901376,  0.16281699,  0.12260573,
#          0.21055334,  0.36306629,  0.10049737,  0.4313571 ,  0.16292785,
#          0.35193   ,  0.42739819,  0.27794228,  0.23399807,  0.37277662,
#          0.37774744,  0.11696618,  0.133365  ,  0.40011533,  0.3223906 ,
#          0.4075792 ,  0.03198901,  0.41944772,  0.23367999,  0.26680927,
#          0.36674255,  0.09631995,  0.19515611,  0.17779976,  0.26274216,
#          0.1111758 ,  0.22023156,  0.41990222,  0.11098568,  0.2624398 ,
#          0.30702721,  0.11994725,  0.43345172,  0.19028792,  0.12976812,
#          0.22198435,  0.23907114,  0.22962192,  0.23040825,  0.13997838,
#          0.33336251]))

# %%
coef, intercept = model.coef_, model.intercept_
coef, intercept
# Out:
# (array([-0.13969547]), 0.24117719950433708)

# %%
lineOfBestFit = coef * merged_data['Value'] + intercept

# %%
# Plot the original data points and the polynomial regression curve

x_range = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
# Predict using the trained model
y_pred2 = model.predict(x_range)

plt.scatter(X, y_train, label='Data Points')
plt.scatter(x_test, y_pred, label='My Predicted Data Points', color='green')
#plt.plot(X['Value'], lineOfBestFit, color='r', label='Polynomial Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Linear Regression')
plt.show()
